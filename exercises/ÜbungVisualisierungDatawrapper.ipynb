# %% [markdown]
# <a href="https://colab.research.google.com/github/redadmiral/python-for-journalists/blob/main/exercises/%C3%9CbungVisualisierungDatawrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Übung Datenvisualisierung
#
# 1. Lade den Datensatz mit den Hundenamen (https://data.stadt-zuerich.ch/dataset/sid_stapo_hundenamen_od1002/download/KUL100OD1002.csv). Finde heraus, wie viele Hunde über die Jahre Coco hießen.

# %% [markdown]
# 1.2 Visualisiere dein Ergebnis mit Datawrapper. Dein Ergebnis sollte ähnlich wie das Chart unten aussehen.

# %% [markdown]
# ![04uoH-hunde-mit-namen-coco-.png](data:image/png;base64,...)
#
# https://datawrapper.dwcdn.net/04uoH/1/

# %% [markdown]
# ## Karten
#
# 2.1 Ließ den Datensatz aller gemeldeten Hunde (https://data.stadt-zuerich.ch/dataset/sid_stapo_hundebestand_od1001/download/KUL100OD1001.csv) in die Variable `dogs` ein.

# %% [markdown]
# 2.2 Ersetze alle Werte 999 in der Spalte die das Alter der Hundebesitzer\*innen enthält durch `np.nan`.

# %% [markdown]
# 2.3 Finde heraus wie alt die Hundebesitzer\*innen im Mittel in jedem Stadtviertel sind.

# %% [markdown]
# 2.4 Erstelle eine Choropleth-Karte auf Datawrapper mit dem durchschnittlichen Alter der Hundebesitzer\*innen, fülle alle wichtigen Felder aus und lass dir einen sprechenden Titel und Beschreibung einfallen.
#
# Veröffentliche die Grafik und kopiere den Link und ein Bild der Grafik in die Zelle unten.
#
# Bonus: Versuche in Datawrapper das durchschnittliche Alter mit nur einer Nachkommastelle darstellen zu lassen.

# %% [markdown]
# ![cLubK-alter-hundebesitzer-innen-in-z-rich.png](data:image/png;base64,...)
#
# https://datawrapper.dwcdn.net/cLubK/1/
